# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import os

# %%
data_dir = "MangoLeaf"
img_size = (224, 224)
batch_size = 32

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

class_names = train_ds.class_names
print("Classes:", class_names)
# Out:
# Found 4000 files belonging to 8 classes.
# Using 3200 files for training.
# Found 4000 files belonging to 8 classes.
# Using 800 files for validation.
# Classes: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']

# %%
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
import tensorflow as tf
import keras

base_model = keras.applications.EfficientNetV2B0(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    include_preprocessing=True,
    name="efficientnetv2-b0",
)
base_model.trainable = False  # Freeze base for transfer learning

inputs = tf.keras.Input(shape=img_size + (3,))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
outputs = Dense(len(class_names), activation="softmax")(x)
model = Model(inputs, outputs)

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 22
#      20 inputs = tf.keras.Input(shape=img_size + (3,))
#      21 x = base_model(inputs, training=False)
# ---> 22 x = GlobalAveragePooling2D()(x)
#      23 x = Dropout(0.2)(x)
#      24 outputs = Dense(len(class_names), activation="softmax")(x)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\input_spec.py:186, in assert_input_compatibility(input_spec, inputs, layer_name)
#     184 if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#     185     if ndim != spec.ndim:
# --> 186         raise ValueError(
#     187             f'Input {input_index} of layer "{layer_name}" '
#     188             "is incompatible with the layer: "
#     189             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     190             f"Full shape received: {shape}"
#     191         )
#     192 if spec.max_ndim is not None:
#     193     if ndim is not None and ndim > spec.max_ndim:
#
# ValueError: Input 0 of layer "global_average_pooling2d_6" is incompatible with the layer: expected ndim=4, found ndim=2. Full shape received: (None, 1000)

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_19 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-b0 (Functional)  │ (None, 7, 7, 1280)     │     5,919,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_8      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │        10,248 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,929,560 (22.62 MB)
#  Trainable params: 10,248 (40.03 KB)
#  Non-trainable params: 5,919,312 (22.58 MB)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 91s 818ms/step - accuracy: 0.6673 - loss: 1.1102 - val_accuracy: 0.9675 - val_loss: 0.2314
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 70s 702ms/step - accuracy: 0.9502 - loss: 0.2347 - val_accuracy: 0.9862 - val_loss: 0.1288
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 77s 767ms/step - accuracy: 0.9808 - loss: 0.1344 - val_accuracy: 0.9912 - val_loss: 0.0872
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 72s 721ms/step - accuracy: 0.9849 - loss: 0.0993 - val_accuracy: 0.9950 - val_loss: 0.0658
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 68s 680ms/step - accuracy: 0.9874 - loss: 0.0794 - val_accuracy: 0.9950 - val_loss: 0.0523
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 67s 673ms/step - accuracy: 0.9905 - loss: 0.0627 - val_accuracy: 0.9950 - val_loss: 0.0427
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 67s 667ms/step - accuracy: 0.9942 - loss: 0.0515 - val_accuracy: 0.9950 - val_loss: 0.0369
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 73s 737ms/step - accuracy: 0.9944 - loss: 0.0441 - val_accuracy: 0.9950 - val_loss: 0.0316
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 77s 771ms/step - accuracy: 0.9939 - loss: 0.0420 - val_accuracy: 0.9950 - val_loss: 0.0281
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 811ms/step - accuracy: 0.9972 - loss: 0.0326 - val_accuracy: 0.9962 - val_loss: 0.0244

# %%
loss, acc = model.evaluate(val_ds)
print(f"Validation accuracy: {acc:.2f}")

# Test on individual images
import numpy as np
import matplotlib.pyplot as plt

# Get a batch of validation images
test_images, test_labels = next(iter(val_ds))

# Make predictions
predictions = model.predict(test_images)

# Plot a grid of images with their predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(test_images[i].numpy().astype("uint8"))
    predicted_class = class_names[np.argmax(predictions[i])]
    true_class = class_names[test_labels[i]]
    color = 'green' if predicted_class == true_class else 'red'
    plt.title(f'Pred: {predicted_class}\nTrue: {true_class}', color=color)
    plt.axis('off')
plt.tight_layout()
plt.show()

# Print classification report
from sklearn.metrics import classification_report
y_pred = []
y_true = []

for images, labels in val_ds:
    predictions = model.predict(images)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(labels.numpy())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9991 - loss: 0.0206
# Validation accuracy: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       1.00      0.99      1.00       104
# Bacterial Canker       1.00      1.00      1.00        94
#   Cutting Weevil       1.00      1.00      1.00        95
#         Die Back       1.00      1.00      1.00        97
#       Gall Midge       0.99      1.00      0.99        94
#          Healthy       1.00      1.00      1.00       111
#   Powdery Mildew       0.99      0.99      0.99       109
#      Sooty Mould       0.99      0.99      0.99        96
#
#         accuracy                           1.00       800
#        macro avg       1.00      1.00      1.00       800
#     weighted avg       1.00      1.00      1.00       800

# %%
# Save the model in SavedModel format
model.save('efficient_net_v2b0_model.keras')

# Save the model weights
model.save_weights('efficient_net_v2b0_weights.weights.h5')

# %%
model = tf.keras.models.load_model('models/efficient_net_v2b0_model.keras')

predictions = model.predict(test_images)

# Plot a grid of images with their predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(test_images[i].numpy().astype("uint8"))
    predicted_class = class_names[np.argmax(predictions[i])]
    true_class = class_names[test_labels[i]]
    color = 'green' if predicted_class == true_class else 'red'
    plt.title(f'Pred: {predicted_class}\nTrue: {true_class}', color=color)
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
model = tf.keras.models.load_model('models/efficient_net_v2b0_model.keras')

# %%
# Using TFlite to compact the model with INT8 quantization
import tensorflow as tf
import numpy as np
import os # For file size comparison, if desired


# 1. Initialize the TFLite converter from the Keras model
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 2. Specify INT8 quantization (post-training integer quantization)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

def representative_data_gen():
    for images, _ in train_ds.take(100):  # Use até 100 batches para calibrar
        yield [images]
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

tflite_model = converter.convert()

# Salve o modelo quantizado
with open("efficientnetv2b0_quant_int8.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\saulo\AppData\Local\Temp\tmpsllg3ymn\assets
# INFO:tensorflow:Assets written to: C:\Users\saulo\AppData\Local\Temp\tmpsllg3ymn\assets
# Saved artifact at 'C:\Users\saulo\AppData\Local\Temp\tmpsllg3ymn'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_19')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   2139374331536: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2139374331344: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2139374324816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374332304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374333072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374332112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374331920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374333264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374334224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374334992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374330576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374333648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374335184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374336144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374336912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374334032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374335568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374337104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377139984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377140752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374337872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139374337488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377140176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377141712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377142480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377139792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377141136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377142672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377143632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377144400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377141520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377143056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377143824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377145936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377146704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377145744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377145552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377146896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377147856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377148624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377145360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377147280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377148816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377150544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377147664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377149200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377150736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377151696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377152464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377149584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377151120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377151888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377153808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377154960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377155344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377468624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377155920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377468432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377467856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377469200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377467664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377469584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377470352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377471504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377469968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377470736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377469008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377472080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377474576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377475344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377474000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377474384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377478032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377478224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377482256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377482064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377893648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377894608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377894224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377894992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377896144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377893456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377895376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377895568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377897680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377898448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377897488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377897296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377898640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377899600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377900368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377897104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377899024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377900560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377899408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377901520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377900944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377901904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377902672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377903824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377902288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377903056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377904016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377904976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377905744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377901328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377904400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377905936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377906896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377907664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377904784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377906320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377907856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377906704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377908816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377908624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377909584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378303632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378303248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139377908240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378304400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378303824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378305936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378306704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378305744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378305552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378306896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378307856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378308624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378305360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378307280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378308816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378307664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378309776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378309200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378310160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378310928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378310544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378311504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378313424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378314576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378315536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378313040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378314960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378316496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378315344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378317840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378679888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378680464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378681808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378682576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378681616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378681424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378682768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378683728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378684496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378681232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378683152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378684688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378683536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378685648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378685072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378686032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378686800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378687952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378686416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378687184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378687376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378689488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378690256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378689296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378689104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378690448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378691408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378692176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378688912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378690832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378692368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378691216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378693328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378692752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378693712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378694480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378695632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378694096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378694864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378693136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379106256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379106832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139378695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379107024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379107408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379108368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379109136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379106064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379107792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379109328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379108176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379110288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379109712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379110672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379111440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379112592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379111056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379111824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379112016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379114128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379114896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379113936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379113744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379115088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379116048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379116816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379115472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379117008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379118352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379119120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379120272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379119504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379119696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379532240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379121232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379533392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379532816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379533200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379535312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379534736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379535696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379536080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379536848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379537040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379539152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379539920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379538960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379538768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379541072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379541840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379538576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379540496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379542032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379540880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379542992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379542416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379543376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379544144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379545296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379543760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379544528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379544720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379546832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379547600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379546640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379546448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379546256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139379547408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414673168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414673936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414672976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414674128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415134288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414674896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139414675280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415134864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415135248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415135824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415135056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415136208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415136976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415138128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415136592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415137360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415137552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415139664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415140432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415139472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415139280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415139856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2139415142160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# C:\Users\saulo\AppData\Roaming\Python\Python312\site-packages\tensorflow\lite\python\convert.py:983: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(

# %%
import tensorflow as tf
import numpy as np

# Carregue o modelo TFLite
interpreter = tf.lite.Interpreter(model_path="efficientnetv2b0_quant_int8.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Função para pré-processar e quantizar as imagens
def preprocess_and_quantize(image):
    # Normalização e resize já devem ter sido feitos pelo dataset
    # Aqui, convertemos para uint8 se necessário
    if input_details[0]['dtype'] == np.uint8:
        image = (image.numpy() * 255).astype(np.uint8)
    return image

y_true = []
y_pred = []

for images, labels in val_ds:
    for i in range(images.shape[0]):
        img = images[i:i+1]  # shape (1, h, w, c)
        label = labels[i].numpy()
        
        # Quantize se necessário
        if input_details[0]['dtype'] == np.uint8:
            img = (img.numpy() * 255).astype(np.uint8)
        else:
            img = img.numpy()
        
        interpreter.set_tensor(input_details[0]['index'], img)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details[0]['index'])
        pred = np.argmax(output, axis=1)[0]
        
        y_true.append(label)
        y_pred.append(pred)

from sklearn.metrics import accuracy_score, classification_report

print("Acurácia TFLite INT8:", accuracy_score(y_true, y_pred))
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Acurácia TFLite INT8: 0.155
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.00      0.00      0.00       104
# Bacterial Canker       0.07      0.04      0.05        94
#   Cutting Weevil       0.54      0.16      0.24        95
#         Die Back       0.00      0.00      0.00        97
#       Gall Midge       1.00      0.01      0.02        94
#          Healthy       0.15      0.93      0.25       111
#   Powdery Mildew       0.14      0.01      0.02       109
#      Sooty Mould       0.00      0.00      0.00        96
#
#         accuracy                           0.15       800
#        macro avg       0.24      0.14      0.07       800
#     weighted avg       0.23      0.15      0.08       800

# %%
import tensorflow as tf
import numpy as np

# Carregue o modelo TFLite
interpreter = tf.lite.Interpreter(model_path="efficient_net_v2b0_quant_int8.tflite")

interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Função para pré-processar e quantizar as imagens
def preprocess_and_quantize(image):
    # Normalização e resize já devem ter sido feitos pelo dataset
    # Aqui, convertemos para uint8 se necessário
    if input_details[0]['dtype'] == np.int8:
        image = (image.numpy() * 255).astype(np.int8)
    return image

y_true = []
y_pred = []

for images, labels in val_ds:
    for i in range(images.shape[0]):
        img = preprocess_and_quantize(images[i:i+1])
        label = labels[i].numpy()
        
        interpreter.set_tensor(input_details[0]['index'], img)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details[0]['index'])
        pred = np.argmax(output, axis=1)[0]
        
        y_true.append(label)
        y_pred.append(pred)

from sklearn.metrics import accuracy_score, classification_report

print("Acurácia TFLite INT8:", accuracy_score(y_true, y_pred))
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Acurácia TFLite INT8: 0.2475
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.05      0.01      0.02       104
# Bacterial Canker       0.42      0.61      0.50        94
#   Cutting Weevil       0.68      0.14      0.23        95
#         Die Back       0.00      0.00      0.00        97
#       Gall Midge       0.00      0.00      0.00        94
#          Healthy       0.19      0.97      0.32       111
#   Powdery Mildew       0.37      0.17      0.23       109
#      Sooty Mould       0.20      0.01      0.02        96
#
#         accuracy                           0.25       800
#        macro avg       0.24      0.24      0.16       800
#     weighted avg       0.24      0.25      0.17       800
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
import tensorflow as tf
import keras

base_model = keras.applications.EfficientNetV2B0(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
    include_preprocessing=True,
    name="efficientnetv2-b0",
)
base_model.trainable = False  # Freeze base for transfer learning

inputs = tf.keras.Input(shape=img_size + (3,))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.2)(x)
outputs = Dense(len(class_names), activation="softmax")(x)
model = Model(inputs, outputs)

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[19], line 22
#
#      20 inputs = tf.keras.Input(shape=img_size + (3,))
#
#      21 x = base_model(inputs, training=False)
#
# ---> 22 x = GlobalAveragePooling2D()(x)
#
#      23 x = Dropout(0.2)(x)
#
#      24 outputs = Dense(len(class_names), activation="softmax")(x)
#
#
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
#     120     # To get the full stack trace, call:
#
#     121     # `keras.config.disable_traceback_filtering()`
#
# --> 122     raise e.with_traceback(filtered_tb) from None
#
#     123 finally:
#
#     124     del filtered_tb
#
#
#
# File ~\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\input_spec.py:186, in assert_input_compatibility(input_spec, inputs, layer_name)
#
#     184 if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#
#     185     if ndim != spec.ndim:
#
# --> 186         raise ValueError(
#
#     187             f'Input {input_index} of layer "{layer_name}" '
#
#     188             "is incompatible with the layer: "
#
#     189             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#
#     190             f"Full shape received: {shape}"
#
#     191         )
#
#     192 if spec.max_ndim is not None:
#
#     193     if ndim is not None and ndim > spec.max_ndim:
#
#
#
# ValueError: Input 0 of layer "global_average_pooling2d_6" is incompatible with the layer: expected ndim=4, found ndim=2. Full shape received: (None, 1000)

# %%
# Using TFlite to compact the model with INT8 quantization
import tensorflow as tf
import numpy as np
import os # For file size comparison, if desired


# 1. Initialize the TFLite converter from the Keras model
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 2. Specify INT8 quantization (post-training integer quantization)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# 3. Define the representative dataset generator
# This generator provides a few samples from your test data to calibrate the quantization parameters.
def representative_data_gen():
    # Number of calibration samples. 100-300 is a common range.
    num_calibration_samples = 100
    
    # Ensure test_images is accessible and has the expected format
    if 'test_images' not in globals():
        raise NameError("'test_images' is not defined. Please ensure it's loaded.")
    if not hasattr(test_images, 'shape'):
        raise TypeError("'test_images' does not have a shape attribute. Expected NumPy array or TF Tensor.")

    for i in range(min(num_calibration_samples, test_images.shape[0])):
        # Get a single sample image
        sample = test_images[i]
        
        # The Keras model expects float32 input.
        # The generator must yield a list of input tensors.
        # Add a batch dimension if the sample is a single image (H, W, C) -> (1, H, W, C)
        # Convert to NumPy array of type float32.
        if isinstance(sample, tf.Tensor):
            sample_np = sample.numpy()
        else:
            sample_np = sample # Assuming it's already a NumPy array

        if len(sample_np.shape) == 3: # (H, W, C)
            input_tensor = np.expand_dims(sample_np, axis=0).astype(np.float32)
        elif len(sample_np.shape) == 4 and sample_np.shape[0] == 1: # Already (1, H, W, C)
            input_tensor = sample_np.astype(np.float32)
        else:
            raise ValueError(f"Sample shape {sample_np.shape} is not suitable. Expected (H,W,C) or (1,H,W,C).")
            
        yield [input_tensor]

# 4. Set the representative dataset for calibration
converter.representative_dataset = representative_data_gen

# 5. Enforce full integer quantization for all operations, including input and output
# This makes the model run entirely on integer hardware if possible.
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

# 6. Set the input and output tensors' data types to INT8
# This means the TFLite model will expect INT8 input and produce INT8 output.
# If your application provides float32 and expects float32, TFLite runtime
# will add quantize/dequantize ops if these are not tf.float32.
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8 # Can also be tf.float32 if preferred for output layer

# 7. Convert the model to TFLite format
try:
    tflite_quant_model = converter.convert()

    # 8. Save the quantized TFLite model to a file
    tflite_model_path = 'efficient_net_v2b0_quant_int8.tflite'
    with open(tflite_model_path, 'wb') as f:
        f.write(tflite_quant_model)
    
    print(f"Successfully converted and saved INT8 quantized model to {tflite_model_path}")

    # Compare model sizes (optional)
    original_model_path = 'models/efficient_net_v2b0_model.keras' # Path from cell 8
    if os.path.exists(original_model_path):
        original_model_size = os.path.getsize(original_model_path) / (1024 * 1024)
        print(f"Original Keras model size: {original_model_size:.2f} MB")
    else:
        # Fallback for .weights.h5 if .keras directory not found or size is tricky for SavedModel format
        original_weights_path = 'efficient_net_v2b0_weights.weights.h5' # From cell 7
        if os.path.exists(original_weights_path):
            original_weights_size = os.path.getsize(original_weights_path) / (1024 * 1024)
            print(f"Original model weights size (approx.): {original_weights_size:.2f} MB")
        else:
            print(f"Original Keras model file not found at {original_model_path} or {original_weights_path} for size comparison.")


    tflite_model_size = len(tflite_quant_model) / (1024 * 1024)
    print(f"Quantized TFLite model size: {tflite_model_size:.2f} MB")
    reduction_percentage = ((original_model_size - tflite_model_size) / original_model_size) * 100 if 'original_model_size' in locals() and original_model_size > 0 else "N/A"
    if reduction_percentage != "N/A":
        print(f"Model size reduction: {reduction_percentage:.2f}%")


except Exception as e:
    print(f"Error during TFLite INT8 quantization: {e}")
    print("\nCommon issues to check:")
    print("1. 'model' variable: Is it loaded and a valid Keras model?")
    print("2. 'test_images' variable: Is it defined, correctly preprocessed (e.g., normalized, resized), and in the format expected by the Keras model?")
    print("   The representative_dataset_gen expects 'test_images' to be a NumPy array or TF Tensor.")
    print("3. Model architecture: Does the model contain operations not supported by TFLITE_BUILTINS_INT8? If so, conversion might fail or require custom ops.")
    print("4. TensorFlow version: Ensure you are using a compatible version of TensorFlow (usually 2.x for these features).")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\saulo\AppData\Local\Temp\tmp2y12gh4n\assets
# INFO:tensorflow:Assets written to: C:\Users\saulo\AppData\Local\Temp\tmp2y12gh4n\assets
# Saved artifact at 'C:\Users\saulo\AppData\Local\Temp\tmp2y12gh4n'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_19')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   1520090266320: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   1520090266512: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   1520090266704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090265360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090265936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090265744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090258448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149872720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090264976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520090267472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149872912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149874256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149875024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149873680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149873488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149875216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149876176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149876944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149874064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149875600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149877136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149878096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149878864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149875984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149877520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149879056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149880016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149880784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149877904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149879440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149882320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149883088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149881936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149883280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149885200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149886160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149886928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149885584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149887120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149885968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520149887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150237584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150237968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150238928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150239312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150241040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150242000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150244688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150245840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150246992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150246608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150675728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150676496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150676688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150677648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150678416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150675536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150677072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150677456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150679568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150678992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150679952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150681872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150680336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150681104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150681296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150683408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150684176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150683216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150683024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150684368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150685328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150686096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150684752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150686288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150685136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150687248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150686672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150687632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150688400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150689552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150688016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150688784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150689744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150690704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150691472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150687056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150690128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520150691280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151135056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151134288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151135248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151134480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151136016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151135632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151136976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151136400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151137360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151138128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151139280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151137744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151138512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151138704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151140816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151141584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151140624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151140432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151141776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151142736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151143504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151140240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151142160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151143696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151142544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151144656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151144080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151145040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151145808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151146960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151145424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151146192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151146384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151148496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151149264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151148304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151148112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151149456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151149840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151577232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151150224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151150416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151577424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151576656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151578384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151577808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151578768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151579536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151580688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151579152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151579920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151580112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151582224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151582992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151582032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151581840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151583184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151584144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151584912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151581648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151583568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151585104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151583952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151586064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151585488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151586448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151587216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151588368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151586832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151587600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151587792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151589904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151589712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151589520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151590864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151591824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151592592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151589328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151591248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520151592400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152052560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152052752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152053328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152052944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152053712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152054864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152051792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152054096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152055056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152056016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152056784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152051984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152055440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152057936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152058704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152055824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152057360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152058896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152059856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152059280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152060240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152061008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152062160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152060624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152061392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152061584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152063696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152063504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152063312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152064656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152065616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152066384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152063120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152065040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152066576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152067344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152065424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152065808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152066960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152495312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152495888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152495120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152494160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152495696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152497424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152497232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152497040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152498384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152499344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152500112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152496848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152498768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152500304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152499152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152501264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152500688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152502416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152503568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152502032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152502800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152502992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152505104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152505872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152504912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152504720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152506064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152507024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152507792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152504528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152506448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152507984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152506832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152508944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152509520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152508368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158769616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158770192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152510096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520152509712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158769424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158771536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158772304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158771344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158771152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158772496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158770960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158772880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158774416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158773264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158775376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158774800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158775760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158776528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158777680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158776144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158777104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158779216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158779984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158779024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158778832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158780176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158781136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158781904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158778640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158780560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158782096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158780944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158782480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158783440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158784208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158785168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158783824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520158784592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159179216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159180176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159179984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159181136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159182864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159178832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159181520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159183056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159181904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159184016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159183440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159185168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1520159190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
# C:\Users\saulo\AppData\Roaming\Python\Python312\site-packages\tensorflow\lite\python\convert.py:983: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Successfully converted and saved INT8 quantized model to efficient_net_v2b0_quant_int8.tflite
# Original Keras model size: 23.58 MB
# Quantized TFLite model size: 6.81 MB
# Model size reduction: 71.14%

# %%
# Print model size comparison
keras_size = os.path.getsize('models/efficient_net_v2b0_model.keras') / (1024*1024)
tflite_size = os.path.getsize('efficient_net_v2b0_quant_int8.tflite') / (1024*1024)
print(f'Original Keras model size: {keras_size:.2f} MB')
print(f'TFLite model size: {tflite_size:.2f} MB')
print(f'Size reduction: {((keras_size-tflite_size)/keras_size)*100:.1f}%')
# Out:
# Original Keras model size: 23.58 MB
# TFLite model size: 6.81 MB
# Size reduction: 71.1%

# %%
# Assuming numpy as np, tensorflow as tf, and os are already imported in previous cells.

# Run inference on the quantized INT8 TFLite model using test data from test_ds

# Load the TFLite model and allocate tensors
interpreter = tf.lite.Interpreter(model_path="efficient_net_v2b0_quant_int8.tflite")
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Prepare to collect predictions and true labels
predictions = []
true_labels = []



# Fix the INT8 quantization issue
print("\nThe error occurred because we're trying to feed float32 data to an INT8 quantized model.")
print("Let's modify the inference code to properly quantize the input:")

def run_quantized_inference(interpreter, test_images, test_labels, num_samples=None):
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    # Get quantization parameters
    input_scale, input_zero_point = input_details[0]['quantization']
    
    if num_samples is None:
        num_samples = len(test_images)
    else:
        num_samples = min(num_samples, len(test_images))
    
    predictions = []
    true_labels = []
    
    for i in range(num_samples):
        img = test_images[i]
        
        # Convert from float to int8
        if isinstance(img, tf.Tensor):
            img = img.numpy()
        
        # Ensure the image has the right shape
        if len(img.shape) < 4:
            img = np.expand_dims(img, axis=0)
        
        # Quantize the input from float to int8
        img_quantized = np.asarray((img / input_scale) + input_zero_point, dtype=np.int8)
        
        # Set the input tensor
        interpreter.set_tensor(input_details[0]['index'], img_quantized)
        
        # Run inference
        interpreter.invoke()
        
        # Get the output tensor
        output_data = interpreter.get_tensor(output_details[0]['index'])
        predictions.append(output_data[0])
        
        # Store the true label
        if isinstance(test_labels[i], tf.Tensor):
            true_labels.append(test_labels[i].numpy())
        else:
            true_labels.append(test_labels[i])
    
    return np.array(predictions), np.array(true_labels)

# Try running inference with the quantized function
print("\nRunning inference with proper quantization...")
predictions, true_labels = run_quantized_inference(interpreter, test_images, test_labels)

# Calculate accuracy
if len(true_labels) > 0:
    if len(true_labels.shape) > 1 and true_labels.shape[1] > 1:
        # One-hot encoded labels
        predicted_classes = np.argmax(predictions, axis=1)
        true_classes = np.argmax(true_labels, axis=1)
    else:
        # Class indices
        predicted_classes = np.argmax(predictions, axis=1)
        true_classes = true_labels
        
    accuracy = np.mean(predicted_classes == true_classes)
    print(f"TFLite INT8 model accuracy on test set (with proper quantization): {accuracy*100:.2f}%")
    
    # Print confusion matrix for first few classes
    cm = confusion_matrix(true_classes, predicted_classes)
    print("Confusion matrix (first 5x5):")
    print(cm[:5, :5])
# Out:
# The error occurred because we're trying to feed float32 data to an INT8 quantized model.
# Let's modify the inference code to properly quantize the input:
#
# Running inference with proper quantization...
# TFLite INT8 model accuracy on test set (with proper quantization): 100.00%
# Confusion matrix (first 5x5):
# [[3 0 0 0 0]
#  [0 7 0 0 0]
#  [0 0 5 0 0]
#  [0 0 0 5 0]
#  [0 0 0 0 1]]
