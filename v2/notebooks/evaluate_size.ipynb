# %%
import tensorflow as tf
import os
import zipfile

# List of models to process
models = {
    'EfficientNetB0': '../../v2/notebooks/models/efficientNetB0.keras',
    'MobileNetV3 Small': '../../v2/notebooks/models/mobilenetv3_small.keras',
    'LCNN': '../../v2/notebooks/models/lcnn_v2.keras',
}

# Process each model
for model_name, model_path in models.items():
    # Load the model
    model = tf.keras.models.load_model(model_path)
    
    # Convert to TFLite
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    tflite_model = converter.convert()
    
    # Save the TFLite model
    tflite_path = f'../../v2/notebooks/models/compressed/{model_name}.tflite'
    with open(tflite_path, 'wb') as f:
        f.write(tflite_model)
    
    # Zip the TFLite model
    zip_path = f'../../v2/notebooks/models/compressed/{model_name}.zip'
    with zipfile.ZipFile(zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as zipf:
        zipf.write(tflite_path)
    
    # Get sizes
    tflite_size = os.path.getsize(tflite_path)
    zip_size = os.path.getsize(zip_path)
    
    # Print sizes
    print(f"{model_name}:")
    print(f"  TFLite size: {tflite_size} bytes ({tflite_size/1024:.2f} KB, {tflite_size/(1024*1024):.2f} MB)")
    print(f"  Zipped size: {zip_size} bytes ({zip_size/1024:.2f} KB, {zip_size/(1024*1024):.2f} MB)")
    print(f"  Compression ratio: {tflite_size/zip_size:.2f}x")
    print()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpy5nsrqao/assets
# INFO:tensorflow:Assets written to: /tmp/tmpy5nsrqao/assets
# Saved artifact at '/tmp/tmpy5nsrqao'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   138444498520784: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   138444498523856: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   138446864883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864882320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864885200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864885776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864883088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864885584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864886160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864886736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864885968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864887120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864886544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864886928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864885392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864887696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864886352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864884816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864887888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864888272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864888848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864889424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864889808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864890384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864889616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864890768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864890192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864890576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864891344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864891536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864891152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864891728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864890000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864882704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864889040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864890960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864887312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502827280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864881168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864013008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864880976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864881360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864880592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446864881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502829200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502828240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502828432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502828048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502829392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502829584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502827856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502828624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502829968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502830544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502828816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502827088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502830352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502830928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502831504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502830736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502831888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502829776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502831312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502831696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502830160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502832464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502831120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502833232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502827472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502832656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502833040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502833616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502834192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502833424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502832848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502834000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502834576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502835152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502834384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502835536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502832272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502834960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502835344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502833808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502836112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502834768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502836880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502837072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502836496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502835728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502837456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502838032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502836688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502836304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502837840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502838416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502838992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502838224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502837264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502838800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502837648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502839952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502838608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502835920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502840528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502832080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502839568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502839760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444502842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500844816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500845008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500845392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500846160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500846736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500845200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500844624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500846544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500847120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500847696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500846928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500848080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500845968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500847504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500847888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500846352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500848656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500847312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500849424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500849616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500849040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500848272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500850000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500850576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500849232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500848848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500850384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444500850960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444
: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868573904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868572560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868571408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868573712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868574864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868574288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868574480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868574672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868572752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868575824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868575248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868573520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868576592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868576016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868576976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868575440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868574096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868576784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868577552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868576208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868575056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868577744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868578128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868577168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868576400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010631376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868577936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446868575632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010630416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010631184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010632144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010631568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010632528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010630800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010630224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010632336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010633104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010631760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010630608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010632912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010630992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010634064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010633488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010633680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010633872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010631952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010634448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010632720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010635792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010635216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010636176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010634640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010633296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010635984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010636752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010635408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010634256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010634832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010637712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010637136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010637328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010637520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010635600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010638672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010638096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010636368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010639440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010638864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010639824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010638288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010636944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010639632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010640400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010639056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010637904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010640208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010638480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010641360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010640784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010640976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010641168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010639248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010642320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010641744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010640016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010643088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010642512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010642896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010643856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010641552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010640592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010644432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010643280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010644048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010644240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010642704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010645392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010644624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010646352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010645584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138446010643664: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1749832430.532701   77152 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1749832430.532739   77152 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-06-13 13:33:50.533076: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpzp2ggfrt
# 2025-06-13 13:33:50.555660: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-06-13 13:33:50.555763: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpzp2ggfrt
# 2025-06-13 13:33:50.969845: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-06-13 13:33:53.134795: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpzp2ggfrt
# 2025-06-13 13:33:53.694939: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 3161861 microseconds.
# MobileNetV3 Small:
#   TFLite size: 4027196 bytes (3932.81 KB, 3.84 MB)
#   Zipped size: 3725375 bytes (3638.06 KB, 3.55 MB)
#   Compression ratio: 1.08x
#
# INFO:tensorflow:Assets written to: /tmp/tmpy0h3utmj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpy0h3utmj/assets
# Saved artifact at '/tmp/tmpy0h3utmj'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   138444482034576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482034000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482032848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482031696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138444482034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
# LCNN:
#   TFLite size: 693004 bytes (676.76 KB, 0.66 MB)
#   Zipped size: 637641 bytes (622.70 KB, 0.61 MB)
#   Compression ratio: 1.09x
# W0000 00:00:1749832437.784874   77152 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1749832437.784986   77152 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-06-13 13:33:57.785853: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpy0h3utmj
# 2025-06-13 13:33:57.788227: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-06-13 13:33:57.788275: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpy0h3utmj
# 2025-06-13 13:33:57.811320: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-06-13 13:33:57.937823: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpy0h3utmj
# 2025-06-13 13:33:57.976621: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 190777 microseconds.

# %%
# Compare the models
print("Model comparison:")
for model_name in models.keys():
    tflite_path = f'../../v2/notebooks/models/compressed/{model_name}.tflite'
    zip_path = f'../../v2/notebooks/models/compressed/{model_name}.zip'
    tflite_size = os.path.getsize(tflite_path)
    zip_size = os.path.getsize(zip_path)
    print(f"{model_name}: {zip_size/(1024*1024):.2f} MB (zipped)")
# Out:
# Model comparison:
# EfficientNetB0: 14.19 MB (zipped)
# MobileNetV3 Small: 3.55 MB (zipped)
# LCNN: 0.61 MB (zipped)
